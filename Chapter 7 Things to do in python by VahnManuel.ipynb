# %%
#7.4
things = ["mozzarella", "cinderella", "salmonella"]
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
#7.5 - It capitalize letter "c" on Cinderella
things = ["mozzarella", "cinderella", "salmonella"]

things[1] = things[1].capitalize()
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %%
#7.6 - It made mozzarella print all upper case
things = ["mozzarella", "cinderella", "salmonella"]

things[0] = things[0].upper()
print(things)
# Out:
# ['MOZZARELLA', 'cinderella', 'salmonella']

# %%
#7.7 - It deleted the salmonella
things = ["mozzarella", "cinderella", "salmonella"]

del things[2]
print(things)
# Out:
# ['mozzarella', 'cinderella']
