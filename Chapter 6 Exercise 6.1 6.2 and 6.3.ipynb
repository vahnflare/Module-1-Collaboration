# %%
#Exercise: 6.1
#Use a simple for loop to go through the list [3, 2, 1, 0] and print each number.
for number in [3, 2, 1, 0]:
    print(number)
# Out:
# 3
# 2
# 1
# 0

# %%
#Exercise: 6.2
#Compare number to guess_me in a while loop and print the correct message until the loop stops.
guess_me = 7
number = 1

while True:
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
        break
    elif number > guess_me:
        print("oops")
        break
    number += 1
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it!

# %%
#Exercise: 6.3
#Use a for loop to compare each number in range(10) to guess_me and print whether it’s too low, found, or too high.
guess_me = 5

for number in range(10):
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
        break
    else:  # number > guess_me
        print("oops")
        break
# Out:
# too low
# too low
# too low
# too low
# too low
# found it!
