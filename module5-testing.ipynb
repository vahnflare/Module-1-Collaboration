# %% [markdown]
# The test results show if the code is working correctly.
#
# When the output shows "OK", it means all tests passed and the program is correct. Each dot (.) represents a successful test.
#
# If there is an error, the program will show a failure message and explain what went wrong, including the expected result and the actual result.
#
# Testing is important because it helps find mistakes early and ensures that the program works properly.
