# %%
#Function Programming - Binary Search
#Test 1
def binary_search(arr, k):
    left = 0
    right = len(arr) - 1
    result = -1  # store smallest index if found

    while left <= right:
        mid = (left + right) // 2

        if arr[mid] == k:
            result = mid
            right = mid - 1  # move left to find smallest index
        elif arr[mid] < k:
            left = mid + 1
        else:
            right = mid - 1

    return result
arr1 = [1, 2, 3, 4, 5]
k = 4
print(binary_search(arr1, k1))
# Out:
# 3

# %%
#Test 2
def binary_search(arr, k):
    left = 0
    right = len(arr) - 1
    result = -1  # store smallest index if found

    while left <= right:
        mid = (left + right) // 2

        if arr[mid] == k:
            result = mid
            right = mid - 1  # move left to find smallest index
        elif arr[mid] < k:
            left = mid + 1
        else:
            right = mid - 1

    return result
arr2 = [11, 22, 33, 44, 55]
k = 445
print(binary_search(arr2, k2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 21
#      19 arr2 = [11, 22, 33, 44, 55]
#      20 k = 445
# ---> 21 print(binary_search(arr2, k2))
#
# NameError: name 'k2' is not defined
